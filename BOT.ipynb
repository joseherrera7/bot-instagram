# %%
from selenium import webdriver
from time import sleep
import datetime
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import random
from selenium.webdriver.support import ui
from selenium.webdriver.support import expected_conditions as EC
import requests

# %%
# Configuración del driver

driver = webdriver.Firefox(executable_path='C:/Users/jcher/Downloads/geckodriver-v0.31.0-win64/geckodriver.exe')

# Ir a instagram
sleep(2)
driver.get('https://www.instagram.com/accounts/login/')
sleep(3)

# Entrar
username = driver.find_element("name",'username')
username.send_keys('cirilobuenasloc')
password = driver.find_element("name",'password')
password.send_keys('Buenasloc98$')
button_login = driver.find_element(By.XPATH,
    '//*[@id="loginForm"]/div/div[3]/button')
button_login.click()
sleep(5)
print('Sesión iniciada')
sleep(5)
driver.get('https://www.instagram.com/p/BnhpAPjHFqoDKcSZ-iyMHhBRR5KGFl4n09hr2g0/')
print('llego a la publicacion')

ahora = datetime.date.today()
fin = ahora + datetime.timedelta(days=+1)


while ahora < fin:
    # Comentario
    #reactions = ['HUEVUDOOOOO 💙', 'CON HUEVOSSSSSS 💙', 'Wow!!💙 ', 'CON HUEVOS LEVANTA LAS PIERNAS!!💙', 'GUAPOGT', 'CHIMAR LA PUSA', 'que guapo dieguito levanta las piernas huevudo']
    reactions = requests.get('https://palabras-aleatorias-public-api.herokuapp.com/onomatopeia/random').json()
    comment_box = ui.WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.CSS_SELECTOR, 'textarea._ablz._aaoc')))
    comment_box.click()
    element = driver.switch_to.active_element
    #element.send_keys(random.choice(reactions))
    element.send_keys(reactions['body']['onomatopeia'])
    element.send_keys(Keys.ENTER)
    print("Enter")
    sleep(120)
# Out:
# C:\Users\jcher\AppData\Local\Temp\ipykernel_10972\1386272964.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(executable_path='C:/Users/jcher/Downloads/geckodriver-v0.31.0-win64/geckodriver.exe')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\jcher\source\python\bot-instagram\BOT.ipynb Cell 2' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/jcher/source/python/bot-instagram/BOT.ipynb#ch0000001?line=0'>1</a> # Configuración del driver
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jcher/source/python/bot-instagram/BOT.ipynb#ch0000001?line=2'>3</a> driver = webdriver.Firefox(executable_path='C:/Users/jcher/Downloads/geckodriver-v0.31.0-win64/geckodriver.exe')
# ...

# %%
reactions = requests.get('https://palabras-aleatorias-public-api.herokuapp.com/onomatopeia/random').json()
print(reactions['body']['onomatopeia'])
# Out:
# bla, bla, bla
